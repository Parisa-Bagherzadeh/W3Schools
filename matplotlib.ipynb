# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
xpoints=np.array([0,6])
ypoints=np.array([0,250])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
xpoints=np.array([1,2,6,8])
ypoints=np.array([10,5,12,20])
plt.plot(xpoints,ypoints)
plt.show()

# %%
ypoints=np.array([10,5,12,20,25,30,3])
plt.plot(ypoints)
plt.show()

# %%
ypoints=np.array([10,5,12,20,25,30,3])
plt.plot(ypoints,marker='o')
plt.show()

# %%
ypoints=np.array([10,5,12,20,25,30,3])
plt.plot(ypoints,marker='*')
plt.show()

# %%
ypoints=np.array([10,5,12,20,25,30,3])
plt.plot(ypoints,marker='^')
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, '*--',c='black',ms=10,mec='r',mfc='g')
plt.show()

# %%
ypoints=np.array([12,32,14,56,20])
plt.plot(ypoints,linestyle='dotted',c='g',lw=5)
plt.show()

# %%
ypoints1=np.array([12,5,20,15,24])
ypoints2=np.array([20,13,2,17,29])

plt.plot(ypoints1,':',lw=5)
plt.plot(ypoints,'--',c='r')

plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

font1={'family':'serif','color':'blue','size':'15'}
plt.title('Sport watch Data',fontdict=font1,loc='left')
plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")
plt.grid()
plt.show()

# %%
ypoints=np.array([12,45,32,17,49,52])
plt.plot(ypoints,c='red')
plt.grid(axis='y',color='g',ls=':',lw=2)
plt.show()

# %%
x=np.array([10,4,32,65,12])
y=np.array([23,52,14,56,70])

plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([34,12,53,5,20])
y=np.array([12,65,25,90,75])

plt.subplot(1,2,2)
plt.plot(x,y)

plt.show()

# %%
x=np.array([10,4,32,65,12])
y=np.array([23,52,14,56,70])

plt.subplot(2,1,1)
plt.title('Sales')
plt.plot(x,y)

x=np.array([34,12,53,5,20])
y=np.array([12,65,25,90,75])

plt.subplot(2,1,2)
plt.title('Time')
plt.plot(x,y)

plt.show()

# %%
x=np.array([10,4,32,65,12])
y=np.array([23,52,14,56,70])

plt.subplot(2,2,1)
plt.plot(x,y)

x=np.array([34,12,53,5,20])
y=np.array([12,65,25,90,75])

plt.subplot(2,2,2)
plt.plot(x,y)

x=np.array([23,65,18,90,42])
y=np.array([47,83,34,56,14])

plt.subplot(2,2,3)
plt.plot(x,y)

x=np.array([54,65,87,90,42])
y=np.array([47,94,34,12,14])

plt.subplot(2,2,4)
plt.plot(x,y)


plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y,color='hotpink')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y,color='#88c999')
plt.show()

# %%
x=np.array([34,12,94,45,67,10,29,46])
y=np.array([67,85,37,55,98,57,11,15])

color=np.array(['green','red','pink','orange','purple','beige','brown','gray'])
sizes = np.array([20,50,100,200,500,1000,60,90])
alpha=np.array([0.2,0.5,1,0.7,0.4,0.8,0.1,0.9])
plt.scatter(x,y,c=color,s=sizes,alpha=alpha)
plt.show()

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array([0, 10, 20, 30, 40, 45, 50, 55, 60, 70, 80, 90, 100])

plt.scatter(x, y, c=colors, cmap='viridis')
plt.colorbar()
plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %%
x=np.array(['a','b','c','d'])
y=np.array([12,3,6,8])
plt.bar(x,y,color='hotpink',width=0.2)
plt.show()

# %%
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.barh(x, y,color='green',height=0.5)
plt.show()

# %%
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %%
y=np.array([23,65,98,23,45,10])

lbl=['1','2','3','4','5','6']
myexplode = [0.2, 0, 0, 0,0,0]
plt.pie(y,labels=lbl,startangle=90,explode=myexplode,shadow=True)
plt.legend(title='Numbers')
plt.show()
